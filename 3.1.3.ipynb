# %%
from data.binary_data import generate_data
from algorithms.perceptron import perceptron_learning, perc_predict
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
from algorithms.delta import delta_rule, delta_predict
import algorithms.plot as p
from data.binary_data import generate_data_ex3, split_50, split_25, split_A
from algorithms.metrics import precision, recall

# %% [markdown]
# ## Non linearly separable dataset

# %%
n = 100
mA = [1.5, 1.5]
sigA = 1
mB = [-2, 1.5]
sigB = 1

X, y = generate_data(n, mA, sigA, mB, sigB, seed=39)

# %%
lr = 0.001
plt.ylim([-2,4])
w_per, history = perceptron_learning(X, y, lr=lr, max_iters=100)
p.plot_boundarys(history,X,y,'perceptron', batch='batch', lr=lr, update_size=0.01)

plt.ylim([-2,4])
w_del, history = delta_rule(X, y, lr=lr, max_iters=100)
p.plot_boundarys(history,X,y,'delta', batch='batch', lr=lr,  update_size=0.01)
# Out:
# Warning: reached maximum numbers of iterations.
# Number of epochs: 100
# break after iteration 23

# %% [markdown]
# ## Part 2 - two clusters of class A

# %%
data_ex3 = generate_data_ex3()
X, y = data_ex3[:, :2], data_ex3[:, 2]
lr = 0.001

# %%
print("PERCEPTRON LEARNING")
plt.ylim([-1.5,1.5])
w_per, history = perceptron_learning(X, y, lr=lr, max_iters=100)
p.plot_boundarys_ex3(history,X,y,'perceptron',  split_type=r'none', update_size=0.01)
y_pred = perc_predict(X, w_per)
precision(y, y_pred)
recall(y, y_pred)

print()
print("DELTA RULE")
plt.ylim([-1.5,1.5])
w_del, history = delta_rule(X, y, lr=lr, max_iters=100)
p.plot_boundarys_ex3(history,X,y,'delta', split_type=r'none',  update_size=0.01)
y_pred = delta_predict(X, w_del)
precision(y, y_pred)
recall(y, y_pred)
# Out:
# PERCEPTRON LEARNING
# Warning: reached maximum numbers of iterations.
# Number of epochs: 100
# Precision for A: 0.6666666666666666, for B: 0.5164835164835165
# Recall for A: 0.12, for B: 0.94
#
# DELTA RULE
# break after iteration 16
# Precision for A: 0.7, for B: 0.7
# Recall for A: 0.7, for B: 0.7

# %% [markdown]
# ### Removed 25% of each class for training

# %%
X_train, X_test, y_train, y_test = split_25(data_ex3)

# %%
print("PERCEPTRON LEARNING")
plt.ylim([-1.5,1.5])
w_per, history = perceptron_learning(X_train, y_train, lr=lr, max_iters=100)
p.plot_boundarys_ex3(history,X,y,'perceptron',  split_type=r'25% of each class', update_size=0.01)
y_pred = perc_predict(X, w_per)
precision(y, y_pred)
recall(y, y_pred)

print()
print("DELTA RULE")
plt.ylim([-1.5,1.5])
w_del, history = delta_rule(X_train, y_train, lr=lr, max_iters=100)
p.plot_boundarys_ex3(history,X,y,'delta', split_type=r'25% of each class',  update_size=0.01)
y_pred = delta_predict(X, w_del)
precision(y, y_pred)
recall(y, y_pred)
# Out:
# PERCEPTRON LEARNING
# Warning: reached maximum numbers of iterations.
# Number of epochs: 100
# Precision for A: 0.7333333333333333, for B: 0.567741935483871
# Recall for A: 0.33, for B: 0.88
#
# DELTA RULE
# break after iteration 16
# Precision for A: 0.7010309278350515, for B: 0.6893203883495146
# Recall for A: 0.68, for B: 0.71

# %% [markdown]
# ### Removed 50% of class B (yellow)

# %%
X_train, X_test, y_train, y_test = split_50(data_ex3, class_label=1)
plt.ylim([-1.5,1.5])
plt.scatter(X_train[:,0],X_train[:,1], c=y_train)
plt.title('Train set')
plt.xlabel(r'$x_1$')
plt.ylabel(r'$x_2$')
# Out:
# Text(0, 0.5, '$x_2$')

# %%
print("PERCEPTRON LEARNING")
plt.ylim([-1.5,1.5])
w_per, history = perceptron_learning(X_train, y_train, lr=lr, max_iters=100)
p.plot_boundarys_ex3(history,X,y,'perceptron',  split_type=r'50% of class B ', update_size=0.01)
y_pred = perc_predict(X, w_per)
precision(y, y_pred)
recall(y, y_pred)

print()
print("DELTA RULE")
plt.ylim([-1.5,1.5])
w_del, history = delta_rule(X_train, y_train, lr=lr, max_iters=100)
p.plot_boundarys_ex3(history,X,y,'delta', split_type=r'50% of class B ',  update_size=0.01)
y_pred = delta_predict(X, w_del)
precision(y, y_pred)
recall(y, y_pred)
# Out:
# PERCEPTRON LEARNING
# Warning: reached maximum numbers of iterations.
# Number of epochs: 100
# Precision for A: 0.7391304347826086, for B: 0.5714285714285714
# Recall for A: 0.34, for B: 0.88
#
# DELTA RULE
# break after iteration 18
# Precision for A: 0.6178343949044586, for B: 0.9302325581395349
# Recall for A: 0.97, for B: 0.4

# %% [markdown]
# ### Removed 50% of class A for training

# %%
X_train, X_test, y_train, y_test = split_50(data_ex3, class_label=-1)
plt.ylim([-1.5,1.5])
plt.scatter(X_train[:,0],X_train[:,1], c=y_train)
plt.title('Train set')
plt.xlabel(r'$x_1$')
plt.ylabel(r'$x_2$')
# Out:
# Text(0, 0.5, '$x_2$')

# %%
X_train, X_test, y_train, y_test = split_50(data_ex3, class_label=-1)
print("PERCEPTRON LEARNING")
plt.ylim([-1.5,1.5])
w_per, history = perceptron_learning(X_train, y_train, lr=lr, max_iters=100)
p.plot_boundarys_ex3(history,X,y,'perceptron',  split_type=r'50% of class A', update_size=0.01)
y_pred = perc_predict(X, w_per)
precision(y, y_pred)
recall(y, y_pred)

print()
print("DELTA RULE")
plt.ylim([-1.5,1.5])
w_del, history = delta_rule(X_train, y_train, lr=lr, max_iters=100)
p.plot_boundarys_ex3(history,X,y,'delta', split_type=r'50% of class A',  update_size=0.01)
y_pred = delta_predict(X, w_del)
precision(y, y_pred)
recall(y, y_pred)
# Out:
# PERCEPTRON LEARNING
# Warning: reached maximum numbers of iterations.
# Number of epochs: 100
# Precision for A: 0.5, for B: 0.5
# Recall for A: 0.01, for B: 0.99
#
# DELTA RULE
# break after iteration 2
# Precision for A: 0.7407407407407407, for B: 0.5375722543352601
# Recall for A: 0.2, for B: 0.93

# %% [markdown]
# ### Removed 20% from left and 80% of right cluster of class A

# %%
X_train, X_test, y_train, y_test = split_A(data_ex3)
plt.ylim([-1.5,1.5])
plt.scatter(X_train[:,0],X_train[:,1], c=y_train)
plt.title('Train set')
plt.xlabel(r'$x_1$')
plt.ylabel(r'$x_2$')
# Out:
# Text(0, 0.5, '$x_2$')

# %%
print("PERCEPTRON LEARNING")
plt.ylim([-1.5,1.5])
w_per, history = perceptron_learning(X_train, y_train, lr=lr, max_iters=100)
p.plot_boundarys_ex3(history,X,y,'perceptron',  split_type=r'20% from l., 80 from r. clust. of A', update_size=0.01)
y_pred = perc_predict(X, w_per)
precision(y, y_pred)
recall(y, y_pred)

print()
print("DELTA RULE")
plt.ylim([-1.5,1.5])
w_del, history = delta_rule(X_train, y_train, lr=lr, max_iters=100)
p.plot_boundarys_ex3(history,X,y,'delta', split_type=r'20% from l., 80 from r. clust. of A',  update_size=0.01)
y_pred = delta_predict(X, w_del)
precision(y, y_pred)
recall(y, y_pred)
# Out:
# PERCEPTRON LEARNING
# Warning: reached maximum numbers of iterations.
# Number of epochs: 100
# Precision for A: 0.8275862068965517, for B: 0.5555555555555556
# Recall for A: 0.24, for B: 0.95
#
# DELTA RULE
# break after iteration 16
# Precision for A: 0.8163265306122449, for B: 0.6026490066225165
# Recall for A: 0.4, for B: 0.91
