# %%
from data.binary_data import generate_data
from algorithms.perceptron import perceptron_learning
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
from algorithms.delta import delta_rule

# %%
n = 100
mA = [1.5, 2.0]
sigA = 0.5
mB = [-2.5, 0]
sigB = 0.5

X, y = generate_data(n, mA, sigA, mB, sigB, seed=4)

# %%
w_per = perceptron_learning(X, y, lr=0.001, max_iters=250)
# Out:
# Number of epochs: 116

# %%
w_del = delta_rule(X, y)

# %%
colors = ['red','green']
plt.scatter(X[:,0], X[:,1], c=y, cmap=matplotlib.colors.ListedColormap(colors), s=2.0)

x1 = np.linspace(-2,2,100)
x2_per = (-w_per[0]*x1 -w_per[2]) / w_per[1]
x2_del = (-w_del[0]*x1 -w_del[2]) / w_del[1]

plt.plot(x1, x2_per, label='perceptron learning')
plt.plot(x1, x2_del, label='delta rule')
plt.legend()
plt.show()

# %%
from algorithms.generalised_delta import TwoLP

# %%
tlp = TwoLP(nodes_num=2, output_dim=1, features_num=3, lr=0.1)

# %%
tlp.train(X, y, epochs=200)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-c77387c87c6d> in <module>
# ----> 1 tlp.train(X, y, epochs=200)
#
# ~/Documents/KTH/S2/ANN/labs/ann_lab1/algorithms/generalised_delta.py in train(self, X, y, epochs)
#      53         X = np.c_[X, np.ones(X.shape[0])]
#      54
# ---> 55         # make row represent one dimension (as in the instruction)
#      56         X = X.T
#      57
#
# ~/Documents/KTH/S2/ANN/labs/ann_lab1/algorithms/generalised_delta.py in forward_pass(self, X)
#      25
#      26     def forward_pass(self, X):
# ---> 27         hin = self.hidden_weights @ X
#      28         hout = np.concatenate((self.activation_function(
#      29             hin), np.ones((1, X.shape[1]))), axis=0)
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 200 is different from 3)

# %%
w_per = tlp.output_weights[0]
colors = ['red','green']

plt.scatter(X[0, :], X[1, :], c=y, cmap=matplotlib.colors.ListedColormap(colors), s=2.0)

x1 = np.linspace(-2,2,100)
x2_per = (w_per[0]*x1 -w_per[2]) / w_per[1]
# x2_del = (-w_del[0]*x1 -w_del[2]) / w_del[1]

plt.plot(x1, x2_per, label='perceptron learning')
# plt.plot(x1, x2_del, label='delta rule')
plt.legend()
plt.show()

# %%
w_per = w_per[0]

# %%
X = X.T
