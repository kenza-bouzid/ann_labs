# %%
import importlib
import numpy as np
import hopfieldNetwork as hn
import matplotlib.pyplot as plt
from utils import plot_distortion_resistance
from utils import plot_attractor_for_pattern

# %%
N2 = 1024
log2N2 = int(np.log2(N2))
pictures_patterns = np.loadtxt('pict.dat', delimiter=',')
pictures_patterns = pictures_patterns.reshape((11, 1024))
pictures_patterns.shape
# Out:
# (11, 1024)

# %%
hop_net = hn.HopfieldNetwork(pictures_patterns[:3,:])

# %%
plot_distortion_resistance(hop_net, pictures_patterns, 0)

# %%
# plot_distortion_resistance(hop_net, pictures_patterns, 0, steps=10)

# %%
plot_distortion_resistance(hop_net, pictures_patterns, 1)

# %%
plot_distortion_resistance(hop_net, pictures_patterns, 2)

# %%
plot_attractor_for_pattern(hop_net, pictures_patterns, pattern_num=0, noise=0.40)
# Out:
# array([-1., -1., -1., ..., -1., -1., -1.])

# %%
att = plot_attractor_for_pattern(hop_net, pictures_patterns, pattern_num=1, noise=0.46, steps=2)

# %%
att2 = plot_attractor_for_pattern(hop_net, pictures_patterns, pattern_num=2, noise=0.42)

# %%
inter, patt, energy = hop_net.update_rule(
    att, 10, verbose=False)
plt.imshow(patt.reshape((32, 32)), cmap="binary")

# %%
np.sum(pictures_patterns[0] == pictures_patterns[1])
# Out:
# 714

# %%
np.sum(pictures_patterns[0] == att)
# Out:
# 889

# %%
np.sum(att == pictures_patterns[1])
# Out:
# 849

# %%
np.sum(pictures_patterns[0] == pictures_patterns[2])
# Out:
# 256

# %%
np.sum(pictures_patterns[2] == pictures_patterns[1])
# Out:
# 296

# %%
np.sum(pictures_patterns[2] == att2)
# Out:
# 903
