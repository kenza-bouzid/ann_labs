# %%
from rbf import LearningMode
from rbf import CentersSampling
from dataset import SinusData
from dataset import SquareData
import utils_test as ut
import plot_utils as pu
import importlib

# %% [markdown]
# ## Sinus Experiments

# %%
sin_data = SinusData(noise=False)

# %%
importlib.reload(pu)
pu.plot_RBF_grid_search(sin_data)
# Out:
# {(10, 0.6): 0.01349322089526956,
#  (10, 0.8): 0.0069993191694081502,
#  (10, 1): 0.0011927564887153548,
#  (10, 1.2): 0.00073871035639459098,
#  (15, 0.6): 0.0026346167460557924,
#  (15, 0.8): 0.00032989074937845268,
#  (15, 1): 4.4188548354913734e-05,
#  (15, 1.2): 0.00023749879371219484,
#  (20, 0.6): 0.00015921474843618781,
#  (20, 0.8): 2.9630212191839343e-06,
#  (20, 1): 1.3115715081857645e-05,
#  (20, 1.2): 2.4894273264404552e-05,
#  (25, 0.6): 2.1967581132311636e-05,
#  (25, 0.8): 1.6051249335886985e-06,
#  (25, 1): 1.1067209847267505e-05,
#  (25, 1.2): 2.0467091243583329e-05}

# %%
importlib.reload(ut)
ut.error_experiment(sin_data, "sinus", LearningMode.BATCH, CentersSampling.LINEAR)
# Out:
# sinus BATCH LINEAR
# Optimal n_nodes RBF for sinus!
# 0.1{'n_nodes': 6, 'err': 0.06821071453849172}
# 0.01{'n_nodes': 8, 'err': 0.009302981595004868}
# 0.001{'n_nodes': 11, 'err': 0.0009046821728022214}
# min_error=9.348460901940473e-06 n_nodes=35

# %%
importlib.reload(ut)
ut.plot_estimate(sin_data, type="sinus", learning_mode=LearningMode.BATCH,
              centers_sampling=CentersSampling.LINEAR, n=30, sigma=1.0)

# %%
importlib.reload(ut)
ut.plot_estimate(sin_data, type="sinus", learning_mode=LearningMode.BATCH,
              centers_sampling=CentersSampling.LINEAR, n=11, sigma=1.0)

# %%
importlib.reload(ut)
ut.error_experiment(sin_data, "sinus", LearningMode.BATCH, CentersSampling.WEIGHTED, weight=0.5, drop=2**8-2**7+2**3+2**2)
# Out:
# sinus BATCH WEIGHTED
# Optimal n_nodes RBF for sinus!
# 0.1{'n_nodes': 6, 'err': 0.04964452473168982}
# 0.01{'n_nodes': 9, 'err': 0.005236473784844376}
# min_error=0.005236473784844376 n_nodes=9

# %%
ut.plot_estimate(sin_data, type="sinus", learning_mode=LearningMode.BATCH,
              centers_sampling=CentersSampling.WEIGHTED,n_iter=6, weight=0.5, drop=2**8-2**7+2**3+2**2+2**5, sigma=1.0)

# %%
square_data = SquareData(noise=False)

# %%
importlib.reload(ut)
ut.error_experiment(square_data, "square", LearningMode.BATCH, CentersSampling.LINEAR)
# Out:
# square BATCH LINEAR
# Optimal n_nodes RBF for square!
# 0.1{'n_nodes': 16, 'err': 0.09709995842098983}
# min_error=0.09361018001292241 n_nodes=20

# %%
ut.plot_estimate(square_data, type="square", learning_mode=LearningMode.BATCH,
              centers_sampling=CentersSampling.LINEAR, n=16, sigma=1.0)

# %%
ut.plot_estimate(square_data, type="square", learning_mode=LearningMode.BATCH,
              centers_sampling=CentersSampling.LINEAR, n=20, sigma=1.0)

# %%
importlib.reload(pu)
pu.plot_RBF_grid_search(square_data)
# Out:
# {(10, 0.6): 0.13713396936206207,
#  (10, 0.8): 0.13161109469000268,
#  (10, 1): 0.13203698047271709,
#  (10, 1.2): 0.1354241948179872,
#  (15, 0.6): 0.098370075971803819,
#  (15, 0.8): 0.10470549546135537,
#  (15, 1): 0.11781421476350967,
#  (15, 1.2): 0.19075366301648689,
#  (20, 0.6): 0.092877927108093089,
#  (20, 0.8): 0.092579353843416715,
#  (20, 1): 0.093610180012922414,
#  (20, 1.2): 0.13194985441505053,
#  (25, 0.6): 0.082462274728540147,
#  (25, 0.8): 0.09429602475621135,
#  (25, 1): 0.096373311848202275,
#  (25, 1.2): 0.12978690027791476}
