# %%
from rbf import LearningMode
from rbf import CentersSampling
from dataset import SinusData
from dataset import SquareData
import utils_test as ut
import plot_utils as pu
import importlib
import numpy as np
from collections import namedtuple

# %%
np.__version__
# Out:
# '1.13.3'

# %% [markdown]
# ## Sinus Experiments

# %%
sin_data = SinusData(noise=False)

# %%
importlib.reload(ut)
ut.plot_estimate(sin_data, type="sinus", learning_mode=LearningMode.HYBRID,
              centers_sampling=CentersSampling.LINEAR, n=15, sigma=0.8, plot_convergence=True)
# Out:
# 100%|██████████| 60/60 [00:00<00:00, 2640.14it/s]
# 100%|██████████| 20/20 [00:21<00:00,  1.06s/it]

# %%
sin_data = SinusData(noise=True)
importlib.reload(ut)
ut.plot_estimate(sin_data, type="sinus", learning_mode=LearningMode.HYBRID,
              centers_sampling=CentersSampling.LINEAR, n=15, sigma=0.8, plot_convergence=True)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 992.03it/s]
# 100%|██████████| 20/20 [00:17<00:00,  1.12it/s]

# %%
square_data = SquareData(noise=False)

# %%
ut.plot_estimate(square_data, type="square", learning_mode=LearningMode.HYBRID,
              centers_sampling=CentersSampling.LINEAR, n=15, sigma=0.6, plot_convergence=True)
# Out:
# 100%|██████████| 60/60 [00:00<00:00, 2356.28it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]1
# 100%|██████████| 20/20 [00:18<00:00,  1.09it/s]

# %%
square_data = SquareData(noise=True)
ut.plot_estimate(square_data, type="square", learning_mode=LearningMode.HYBRID,
              centers_sampling=CentersSampling.LINEAR, n=10, sigma=0.3, plot_convergence=True)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 792.57it/s]
# 100%|██████████| 20/20 [00:14<00:00,  1.39it/s]

# %%
sin_data = SinusData(noise=False)
importlib.reload(ut)
ut.plot_estimate(sin_data, type="sinus", learning_mode=LearningMode.HYBRID,
              centers_sampling=CentersSampling.LINEAR, n=15, sigma=0.8, plot_convergence=True, neigh=3)
# Out:
# 100%|██████████| 60/60 [00:00<00:00, 2613.38it/s]
# 100%|██████████| 20/20 [00:19<00:00,  1.05it/s]

# %%
sin_data = SinusData(noise=False)
importlib.reload(ut)
ut.plot_estimate(sin_data, type="sinus", learning_mode=LearningMode.HYBRID,
              centers_sampling=CentersSampling.LINEAR, n=5, sigma=0.8, plot_convergence=True, neigh=3)
# Out:
# 100%|██████████| 60/60 [00:00<00:00, 4093.00it/s]
# 100%|██████████| 20/20 [00:06<00:00,  3.23it/s]

# %%
sin_data = SinusData(noise=False)
importlib.reload(ut)
ut.plot_estimate(sin_data, type="sinus", learning_mode=LearningMode.HYBRID,
              centers_sampling=CentersSampling.LINEAR, n=5, sigma=0.8, plot_convergence=True, neigh=1)
# Out:
# 100%|██████████| 60/60 [00:00<00:00, 5770.79it/s]
# 100%|██████████| 20/20 [00:07<00:00,  2.55it/s]

# %% [markdown]
# # 2D experiments

# %%
Data = namedtuple('Data', 'x y x_test y_test')
train = np.loadtxt('data_lab2/ballist.dat')
test = np.loadtxt('data_lab2/balltest.dat')
data = Data(train[:, :2], train[:, 2:], test[:, :2], test[:, 2:])

# %%
error, n_nodes = ut.experiment_nodes(data, LearningMode.HYBRID, CentersSampling.DATA)

# plot_error(n_nodes, error, data, learning_mode, centers_sampling)

# plot_estimate(x, y, x_test, y_test, n_nodes=20)
# Out:
# 100%|██████████| 60/60 [00:00<00:00, 5196.22it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-d9e18526c495> in <module>
# ----> 1 error, n_nodes = ut.experiment_nodes(data, LearningMode.HYBRID, CentersSampling.DATA)
#       2
#       3 # plot_error(n_nodes, error, data, learning_mode, centers_sampling)
#       4
#       5 # plot_estimate(x, y, x_test, y_test, n_nodes=20)
#
# d:\insa\5if\KTH\P3\ANN\assignements\ass_1\ann_lab1\lab2\utils_test.py in experiment_nodes(data, learning_mode, centers_sampling, weight, drop, sigma)
#      43     for i in range(start, end):
#      44         experiment(data, learning_mode, centers_sampling,
# ---> 45                    n_nodes, error, n=i, n_iter=i, weight=weight, drop=drop, sigma=sigma)
#      46
#      47     return error, n_nodes
#
# d:\insa\5if\KTH\P3\ANN\assignements\ass_1\ann_lab1\lab2\utils_test.py in experiment(data, learning_mode, centers_sampling, n_nodes, error, n, n_iter, weight, drop, sigma, neigh, max_iter)
#      21     else:
#      22         y_hat, err = rbf_net.hybrid_learning(
# ---> 23             data.x, data.y, data.x_test, data.y_test, neigh=neigh, max_iters=max_iter)
#      24
#      25     if n_nodes != None and error != None:
#
# d:\insa\5if\KTH\P3\ANN\assignements\ass_1\ann_lab1\lab2\rbf.py in hybrid_learning(self, X, f, X_test, f_test, lr, max_iters, seed, eta, neigh)
#     111     def hybrid_learning(self, X, f, X_test, f_test, lr=0.1, max_iters=20, seed=42, eta=0.1, neigh=3):
#     112         self.competitive_learning(X, eta, neigh)
# --> 113         f_hat, error = self.delta_learning(
#     114             X, f, X_test, f_test, lr, max_iters, seed)
#     115         return f_hat, error
#
# d:\insa\5if\KTH\P3\ANN\assignements\ass_1\ann_lab1\lab2\rbf.py in delta_learning(self, X, f, X_test, f_test, lr, max_iters, seed)
#      63
#      64     def delta_learning(self, X, f, X_test, f_test, lr=0.01, max_iters=15, seed=42):
# ---> 65         np.random.seed(seed)
#      66         weights = np.random.normal(
#      67             0, 0.5, (self.n_nodes+1, X.shape[1]))
#
# AttributeError: module 'numpy.random' has no attribute 'default_rng'

# %%
ut.plot_error(n_nodes, error, "2d", LearningMode.HYBRID, CentersSampling.DATA)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-916e6c4d6036> in <module>
# ----> 1 ut.plot_error(n_nodes, error, "2d", LearningMode.HYBRID, CentersSampling.DATA)
#
# NameError: name 'n_nodes' is not defined

# %%
importlib.reload(ut)
ut.plot_RBF_centers_2d(data, n=4, sigma=1.0, neigh=1)
# Out:
# 100%|██████████| 60/60 [00:00<00:00, 4849.65it/s]
# 100%|██████████| 20/20 [00:11<00:00,  1.67it/s]

# %%
importlib.reload(ut)
ut.plot_RBF_predictions_3d(data, n=4, sigma=1.0, neigh=1, axis=0)
# Out:
# 100%|██████████| 60/60 [00:00<00:00, 1298.50it/s]
# 100%|██████████| 20/20 [00:13<00:00,  1.52it/s]

# %%
importlib.reload(pu)
pu.plot_RBF_grid_search(data, weights= [0.2, 0.4, 0.6, 0.8, 1, 1.2, 5], n_nodes=[5, 10, 15, 20, 25, 30, 35, 40], learning_mode=LearningMode.DELTA)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-0cffdff22f47> in <module>
#       1 importlib.reload(pu)
# ----> 2 pu.plot_RBF_grid_search(data, weights= [0.2, 0.4, 0.6, 0.8, 1, 1.2, 5], n_nodes=[5, 10, 15, 20, 25, 30, 35, 40], learning_mode=LearningMode.DELTA)
#
# d:\insa\5if\KTH\P3\ANN\assignements\ass_1\ann_lab1\lab2\plot_utils.py in plot_RBF_grid_search(data, weights, n_nodes, learning_mode)
#      20             else:
#      21                 y_hat, error = rbf_net.delta_learning(
# ---> 22                     data.x, data.y, data.x_test, data.y_test, max_iters=20, lr=0.1)
#      23             results[(rbf_net.n_nodes, w)] = error
#      24
#
# d:\insa\5if\KTH\P3\ANN\assignements\ass_1\ann_lab1\lab2\rbf.py in delta_learning(self, X, f, X_test, f_test, lr, max_iters, seed)
#      59
#      60     def delta_learning(self, X, f, X_test, f_test, lr=0.01, max_iters=15, seed=42):
# ---> 61         weights = np.random.default_rng(seed).normal(
#      62             0, 0.5, (self.n_nodes+1, X.shape[1]))
#      63
#
# AttributeError: module 'numpy.random' has no attribute 'default_rng'
