# %%
from rbf import LearningMode
from rbf import CentersSampling
from dataset import SinusData
from dataset import SquareData
import utils_test as ut
import importlib
import numpy as np

# %% [markdown]
# ## Sinus Experiments

# %%
sin_data = SinusData(noise=False)

# %%
importlib.reload(ut)
ut.plot_estimate(sin_data, type="sinus", learning_mode=LearningMode.HYBRID,
              centers_sampling=CentersSampling.LINEAR, n=11, sigma=1.0)
# Out:
# ...
# 100%|██████████| 250/250 [00:04<00:00, 62.14it/s]

# %%
importlib.reload(ut)
ut.plot_estimate(sin_data, type="sinus", learning_mode=LearningMode.HYBRID,
              centers_sampling=CentersSampling.LINEAR, n=20, sigma=1.0)
# Out:
# ...
# 100%|██████████| 250/250 [00:07<00:00, 34.85it/s]

# %%
square_data = SquareData(noise=False)

# %%
ut.plot_estimate(square_data, type="square", learning_mode=LearningMode.HYBRID,
              centers_sampling=CentersSampling.LINEAR, n=16, sigma=1.0)
# Out:
# ...
# 100%|██████████| 250/250 [00:04<00:00, 52.29it/s]

# %%
ut.plot_estimate(square_data, type="square", learning_mode=LearningMode.HYBRID,
              centers_sampling=CentersSampling.LINEAR, n=20, sigma=1.0)
# Out:
# ...
# 100%|██████████| 250/250 [00:05<00:00, 46.08it/s]
