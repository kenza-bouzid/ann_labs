# %%
from rbf import LearningMode
from rbf import CentersSampling
from dataset import SinusData
from dataset import SquareData
import utils_test as ut
import importlib

# %% [markdown]
# ## Sinus Experiments

# %%
sin_data = SinusData(noise=False)

# %%
importlib.reload(ut)
ut.error_experiment(sin_data, "sinus", LearningMode.BATCH, CentersSampling.LINEAR)
# Out:
# sinus BATCH LINEAR
# Optimal n_nodes RBF for sinus!
# 0.1{'n_nodes': 6, 'err': 0.06815650415124828}
# 0.01{'n_nodes': 8, 'err': 0.009302997199314005}
# 0.001{'n_nodes': 11, 'err': 0.0009116828540489301}
# min_error=1.0106441650539248e-05 n_nodes=30

# %%
importlib.reload(ut)
ut.error_experiment(sin_data, "sinus", LearningMode.BATCH, CentersSampling.WEIGHTED)
# Out:
# sinus BATCH WEIGHTED
# Optimal n_nodes RBF for sinus!
# 0.1{'n_nodes': 8, 'err': 0.037718249015991086}
# 0.01{'n_nodes': 16, 'err': 2.098069761623542e-05}
# 0.001{'n_nodes': 24, 'err': 3.5736115001292165e-05}
# N_nodes not found for the given thresolds!
# min_error=1.1128416815187433e-05 n_nodes=40

# %%
# plot_estimate(sin_data, type="sinus", learning_mode=LearningMode.BATCH,
#               centers_sampling=CentersSampling.LINEAR, n=20, sigma=1.0)
plot_estimate(sin_data, type="sinus", learning_mode=LearningMode.BATCH,
              centers_sampling=CentersSampling.WEIGHTED,n_iter=3, weight=1.0, drop=2**9-1, sigma=1.0)
